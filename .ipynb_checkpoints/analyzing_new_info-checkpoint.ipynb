# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('files_csv/job_postings_fact.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 787686 entries, 0 to 787685
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_id                 787686 non-null  int64
#  1   company_id             787686 non-null  int64
#  2   job_title_short        787686 non-null  object
#  3   job_title              787685 non-null  object
#  4   job_location           786633 non-null  object
#  5   job_via                787677 non-null  object
#  6   job_schedule_type      774981 non-null  object
#  7   job_work_from_home     787686 non-null  bool
#  8   search_location        787686 non-null  object
#  9   job_posted_date        787686 non-null  object
#  10  job_no_degree_mention  787686 non-null  bool
#  11  job_health_insurance   787686 non-null  bool
#  12  job_country            787634 non-null  object
#  13  salary_rate            33100 non-null   object
# ...

# %%
df
# Out:
#          job_id  company_id       job_title_short  \
# 0             0           0          Data Analyst
# 1            55           1        Cloud Engineer
# 2            66           2          Data Analyst
# 3            76           3         Data Engineer
# 4            81           4         Data Engineer
# ...         ...         ...                   ...
# 787681  1146883      787681      Business Analyst
# 787682  1300468       31237          Data Analyst
# 787683   837368         948  Senior Data Engineer
# 787684  1614901         948  Senior Data Engineer
# 787685  1452207         154         Data Engineer
#
#                                                 job_title  \
# 0                                  Marketing Data Analyst
# 1                     Storage and Virtualization Engineer
# 2                           Data Analyst et Scientist F/H
# 3                                           Data Engineer
# 4                                           Data Engineer
# ...

# %%
# Let's create a multiple colums
df_multiple = df[['job_title_short','job_location','job_title','salary_year_avg']]
# Displaying the first 20 rows of the new dataset
df_multiple.head(20)
# Out:
#          job_title_short               job_location  \
# 0           Data Analyst                   Anywhere
# 1         Cloud Engineer        Kuwait City, Kuwait
# 2           Data Analyst              Paris, France
# 3          Data Engineer                 Denver, CO
# 4          Data Engineer                   Anywhere
# 5           Data Analyst          Bangkok, Thailand
# 6          Data Engineer                   Anywhere
# 7   Senior Data Engineer               New York, NY
# 8           Data Analyst                Chicago, IL
# 9          Data Engineer                   Anywhere
# 10         Data Engineer                   Anywhere
# 11         Data Engineer                  Singapore
# 12        Data Scientist  Ho Chi Minh City, Vietnam
# 13         Data Engineer                Atlanta, GA
# 14  Senior Data Engineer           Redwood City, CA
# 15         Data Engineer          Copper Canyon, TX
# 16          Data Analyst                    Denmark
# ...

# %%
# Showing the last 20 rows of the new dataset
df_multiple.tail(20)
# Out:
#              job_title_short                         job_location  \
# 787666         Data Engineer                        Zürich, Swiss
# 787667         Data Engineer                       Bochum, Jerman
# 787668         Data Engineer                      Le Locle, Swiss
# 787669         Data Engineer                     Chemnitz, Jerman
# 787670     Software Engineer                                India
# 787671  Senior Data Engineer                       Berlin, Jerman
# 787672         Data Engineer                       Carouge, Swiss
# 787673         Data Engineer                      München, Jerman
# 787674  Senior Data Engineer                       Berlin, Jerman
# 787675      Business Analyst                   Almaty, Kazakhstan
# 787676         Data Engineer                   Heidelberg, Jerman
# 787677  Senior Data Engineer                    Karlsruhe, Jerman
# 787678      Business Analyst                        Jenewa, Swiss
# ...

# %%
df_multiple.iloc[20:90, 0:4]
# Out:
#               job_title_short                 job_location  \
# 20           Business Analyst              Munich, Germany
# 21              Data Engineer               Burlingame, CA
# 22             Data Scientist                   Irving, TX
# 23             Cloud Engineer        Tel Aviv-Yafo, Israel
# 24             Data Scientist                        Spain
# ..                        ...                          ...
# 85             Data Scientist  Bengaluru, Karnataka, India
# 86             Data Scientist       Rio de Mouro, Portugal
# 87  Machine Learning Engineer                Madrid, Spain
# 88              Data Engineer           Charleroi, Belgium
# 89        Senior Data Analyst        Linthicum Heights, MD
#
#                                             job_title  salary_year_avg
# 20                               Marketing Analyst/in              NaN
# 21                   Data Engineer, Product Analytics         164000.0
# ...

# %%
# Let's display the number of rows and columns using the shape method
df_multiple.shape
# Out:
# (787686, 4)

# %%
df_multiple[df_multiple.job_title_short == 'Data Analyst']
# Out:
#        job_title_short        job_location                       job_title  \
# 0         Data Analyst            Anywhere          Marketing Data Analyst
# 2         Data Analyst       Paris, France   Data Analyst et Scientist F/H
# 5         Data Analyst   Bangkok, Thailand                    Data Analyst
# 8         Data Analyst         Chicago, IL          Full Time Data Analyst
# 16        Data Analyst             Denmark      Data Analyst Hybrid Remote
# ...                ...                 ...                             ...
# 787629    Data Analyst              Mexico  Mbs Sc Codes Reporting Analyst
# 787642    Data Analyst      United Kingdom         Data and Threat Analyst
# 787646    Data Analyst              Jerman               Lead Data Analyst
# 787649    Data Analyst        Jena, Jerman            Data Analyst (m/w/d)
# 787682    Data Analyst  Bad Rodach, Jerman                CRM Data Analyst
#
#         salary_year_avg
# 0                   NaN
# ...

# %%
"""
    Displaying the Data Analyst jobs with the condition of salary_year_avg>100000
"""
df_multiple[(df_multiple.job_title_short == 'Data Analyst') & (df_multiple.salary_year_avg>100000) ]
# Out:
#        job_title_short                 job_location  \
# 960       Data Analyst                   Vienna, VA
# 4813      Data Analyst                 San Jose, CA
# 5785      Data Analyst                    Hong Kong
# 6060      Data Analyst          California City, CA
# 6352      Data Analyst                      Georgia
# ...                ...                          ...
# 785865    Data Analyst  Bengaluru, Karnataka, India
# 786627    Data Analyst                  Chicago, IL
# 787235    Data Analyst            Mountain View, CA
# 787417    Data Analyst             Santa Monica, CA
# 787469    Data Analyst               Fruit Cove, FL
#
#                                                 job_title  salary_year_avg
# 960               Data Analyst II/III (Lending Analytics)         110200.0
# 4813    Business Intelligence Data Analyst - Global Mo...         208500.0
# 5785                            Market Data Manager, APAC         101750.0
# ...

# %%
"""
    Displaying the same result above but now by making sure that we remove the Null values or cells 
    and removing the condition salary_year_avg>100000
"""
df_multiple[(df_multiple.job_title_short == 'Data Analyst') & (df_multiple.salary_year_avg.notna())]
# Out:
#        job_title_short       job_location  \
# 141       Data Analyst        Chicago, IL
# 377       Data Analyst         Irving, TX
# 699       Data Analyst    St. Charles, IL
# 960       Data Analyst         Vienna, VA
# 1022      Data Analyst         Peoria, IL
# ...                ...                ...
# 786030    Data Analyst       Oslo, Norway
# 786627    Data Analyst        Chicago, IL
# 787235    Data Analyst  Mountain View, CA
# 787417    Data Analyst   Santa Monica, CA
# 787469    Data Analyst     Fruit Cove, FL
#
#                                           job_title  salary_year_avg
# 141                                    Data Analyst          85000.0
# 377                                    Data Analyst          50000.0
# 699                                    Data Analyst          75000.0
# 960         Data Analyst II/III (Lending Analytics)         110200.0
# 1022                       Statistical Data Analyst          62500.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 787686 entries, 0 to 787685
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_id                 787686 non-null  int64
#  1   company_id             787686 non-null  int64
#  2   job_title_short        787686 non-null  object
#  3   job_title              787685 non-null  object
#  4   job_location           786633 non-null  object
#  5   job_via                787677 non-null  object
#  6   job_schedule_type      774981 non-null  object
#  7   job_work_from_home     787686 non-null  bool
#  8   search_location        787686 non-null  object
#  9   job_posted_date        787686 non-null  object
#  10  job_no_degree_mention  787686 non-null  bool
#  11  job_health_insurance   787686 non-null  bool
#  12  job_country            787634 non-null  object
#  13  salary_rate            33100 non-null   object
# ...

# %%
# We're going format the job_posted_date into a datetime 
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
# Let's extract the month from the job_posted_date column to create a special column of months  
df['job_posted_month'] = df.job_posted_date.dt.month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 787686 entries, 0 to 787685
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_id                 787686 non-null  int64
#  1   company_id             787686 non-null  int64
#  2   job_title_short        787686 non-null  object
#  3   job_title              787685 non-null  object
#  4   job_location           786633 non-null  object
#  5   job_via                787677 non-null  object
#  6   job_schedule_type      774981 non-null  object
#  7   job_work_from_home     787686 non-null  bool
#  8   search_location        787686 non-null  object
#  9   job_posted_date        787686 non-null  datetime64[ns]
#  10  job_no_degree_mention  787686 non-null  bool
#  11  job_health_insurance   787686 non-null  bool
#  12  job_country            787634 non-null  object
#  13  salary_rate            33100 non-null   object
# ...

# %%
# df_multiple[(df_multiple.job_title_short == 'Data Analyst') & (df_multiple.salary_year_avg.notna())]
df.dropna(subset=['salary_year_avg'], inplace=True)

# %%
df
# Out:
#          job_id  company_id       job_title_short  \
# 18          220          18  Senior Data Engineer
# 21          284          21         Data Engineer
# 54          870          54         Data Engineer
# 97         1785          97        Data Scientist
# 141        2604          54          Data Analyst
# ...         ...         ...                   ...
# 787294   230597      108694        Data Scientist
# 787417   662412         318          Data Analyst
# 787434  1115667       69662     Software Engineer
# 787469   215762          66          Data Analyst
# 787512  1002637        1600   Senior Data Analyst
#
#                                           job_title       job_location  \
# 18                     Senior Data Engineer (Kafka)      United States
# 21                 Data Engineer, Product Analytics     Burlingame, CA
# 54                                    Data Engineer        Ashland, KY
# 97             DATA SCIENTIST / DATABASE PROGRAMMER         Denver, CO
# ...

# %%
# Let's get rid of the salary_hour_avg column using the Drop method
df.drop(labels='salary_hour_avg', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22034 entries, 18 to 787512
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_id                 22034 non-null  int64
#  1   company_id             22034 non-null  int64
#  2   job_title_short        22034 non-null  object
#  3   job_title              22034 non-null  object
#  4   job_location           21748 non-null  object
#  5   job_via                22034 non-null  object
#  6   job_schedule_type      22019 non-null  object
#  7   job_work_from_home     22034 non-null  bool
#  8   search_location        22034 non-null  object
#  9   job_posted_date        22034 non-null  datetime64[ns]
#  10  job_no_degree_mention  22034 non-null  bool
#  11  job_health_insurance   22034 non-null  bool
#  12  job_country            22033 non-null  object
#  13  salary_rate            22034 non-null  object
# ...

# %%
df.describe()
# Out:
#              job_id     company_id                job_posted_date  \
# count  2.203400e+04   22034.000000                          22034
# mean   6.728702e+05   80238.925706  2023-06-12 18:50:17.365208320
# min    9.000000e+01       3.000000            2022-12-31 07:06:39
# 25%    2.155982e+05    1293.000000  2023-03-17 13:06:56.249999872
# 50%    5.533650e+05   11836.000000            2023-06-11 07:01:45
# 75%    1.069310e+06   85301.000000  2023-08-25 20:00:57.750000128
# max    1.826455e+06  786087.000000            2023-12-31 03:12:41
# std    5.186533e+05  149673.599398                            NaN
#
#        salary_year_avg  job_posted_month
# count     22034.000000      22034.000000
# mean     123268.815643          5.889761
# min       15000.000000          1.000000
# 25%       90000.000000          3.000000
# 50%      115000.000000          6.000000
# 75%      150000.000000          8.000000
# max      960000.000000         12.000000
# ...

# %%
df['salary_year_avg'].median()
# Out:
# 115000.0

# %%
df['salary_year_avg'].min()
# Out:
# 15000.0

# %%
df['salary_year_avg'].max()
# Out:
# 960000.0

# %%
min_salary_year_avg = df['salary_year_avg'].idxmin()
min_salary_year_avg
# Out:
# 464591

# %%
max_salary_year_avg = df['salary_year_avg'].idxmax()
max_salary_year_avg
# Out:
# 514435

# %%
# df.iloc[min_salary_year_avg]

# %%
# df.iloc[max_salary_year_avg]

# %%
value_counting = df['job_title_short'].value_counts()
value_counting
# Out:
# job_title_short
# Data Scientist               5926
# Data Analyst                 5463
# Data Engineer                4509
# Senior Data Scientist        1686
# Senior Data Engineer         1594
# Senior Data Analyst          1132
# Business Analyst              617
# Machine Learning Engineer     573
# Software Engineer             469
# Cloud Engineer                 65
# Name: count, dtype: int64

# %%
min_job_title_grouped = df.groupby('job_title_short')['salary_year_avg'].min()
min_job_title_grouped
# Out:
# job_title_short
# Business Analyst             16500.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                15000.0
# Data Scientist               27000.0
# Machine Learning Engineer    30000.0
# Senior Data Analyst          30000.0
# Senior Data Engineer         35000.0
# Senior Data Scientist        45000.0
# Software Engineer            28000.0
# Name: salary_year_avg, dtype: float64

# %%
max_job_title_grouped = df.groupby(['job_title_short'])[['salary_year_avg']].max()
max_job_title_grouped
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                  387460.0
# Cloud Engineer                    280000.0
# Data Analyst                      650000.0
# Data Engineer                     525000.0
# Data Scientist                    960000.0
# Machine Learning Engineer         325000.0
# Senior Data Analyst               425000.0
# Senior Data Engineer              425000.0
# Senior Data Scientist             890000.0
# Software Engineer                 375000.0

# %%
# plt.barh(max_job_title_grouped,min_job_title_grouped)

# %%
counting_job_title_grouped = df.groupby('job_title_short')[['salary_year_avg']].count()
counting_job_title_grouped
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                       617
# Cloud Engineer                          65
# Data Analyst                          5463
# Data Engineer                         4509
# Data Scientist                        5926
# Machine Learning Engineer              573
# Senior Data Analyst                   1132
# Senior Data Engineer                  1594
# Senior Data Scientist                 1686
# Software Engineer                      469

# %%
max_job_title_grouped_countries = df.groupby(['job_title_short','job_country'])[['salary_year_avg']].max()#.head(30)
max_job_title_grouped_countries
# Out:
#                                         salary_year_avg
# job_title_short   job_country
# Business Analyst  Argentina                     79200.0
#                   Australia                    130000.0
#                   Bangladesh                    16500.0
#                   Belgium                       89100.0
#                   Bulgaria                      89100.0
# ...                                                 ...
# Software Engineer Ukraine                       54000.0
#                   United Arab Emirates          79200.0
#                   United Kingdom               160000.0
#                   United States                375000.0
#                   Vietnam                       79200.0
#
# [592 rows x 1 columns]

# %%
# Let's just combine them
job_title_grouped_comb = df.groupby('job_title_short')['salary_year_avg'].agg(['min', 'median', 'max'])
# job_title_grouped_comb = df.groupby(['job_title_short', 'job_location'])['salary_year_avg'].agg(['min', 'median', 'max'])
job_title_grouped_comb
# Out:
#                                min    median       max
# job_title_short
# Business Analyst           16500.0   85000.0  387460.0
# Cloud Engineer             42000.0   90000.0  280000.0
# Data Analyst               25000.0   90000.0  650000.0
# Data Engineer              15000.0  125000.0  525000.0
# Data Scientist             27000.0  127500.0  960000.0
# Machine Learning Engineer  30000.0  106000.0  325000.0
# Senior Data Analyst        30000.0  111175.0  425000.0
# Senior Data Engineer       35000.0  147500.0  425000.0
# Senior Data Scientist      45000.0  155000.0  890000.0
# Software Engineer          28000.0   99150.0  375000.0

# %%
job_title_grouped_comb.plot(kind='line')
plt.ylabel('Average Salary Per Year')
plt.xlabel('')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
job_countries = df['job_country'].value_counts().head(30)
job_countries
# Out:
# job_country
# United States     15813
# Sudan              1612
# India               580
# Canada              459
# United Kingdom      288
# Germany             257
# France              239
# Poland              200
# Spain               144
# Portugal            132
# Mexico              109
# Israel              103
# Singapore            99
# South Africa         91
# Netherlands          86
# Greece               80
# Australia            75
# Colombia             69
# South Korea          68
# Philippines          67
# Brazil               62
# Hungary              62
# Malaysia             60
# Belgium              57
# Vietnam              56
# Switzerland          54
# Thailand             53
# Ireland              51
# Sweden               47
# Italy                47
# Name: count, dtype: int64

# %%
plt.barh(df['job_country'].head(90), df['job_posted_month'].head(90))
plt.show()

# %%
job_cnd = df[df['job_location'] == 'Canada']
job_cnd
# Out:
#          job_id  company_id            job_title_short  \
# 6580     160308        2852              Data Engineer
# 9324     244873        3508              Data Engineer
# 47326    139994       47326               Data Analyst
# 49916    210576       49916              Data Engineer
# 58497    496064         295  Machine Learning Engineer
# ...         ...         ...                        ...
# 756044   743109        1233  Machine Learning Engineer
# 762750    89763       11595        Senior Data Analyst
# 769272   995289       49916               Data Analyst
# 769966  1118880          12  Machine Learning Engineer
# 771757  1499100       34084             Data Scientist
#
#                                                 job_title job_location  \
# 6580                              Data Engineer, Hardware       Canada
# 9324                                        Data Engineer       Canada
# 47326                            Procurement Data Analyst       Canada
# ...

# %%
job_us = df[df['job_country'] == 'United States']
job_us
# Out:
#          job_id  company_id        job_title_short  \
# 21          284          21          Data Engineer
# 54          870          54          Data Engineer
# 97         1785          97         Data Scientist
# 141        2604          54           Data Analyst
# 191        3569         191  Senior Data Scientist
# ...         ...         ...                    ...
# 787294   230597      108694         Data Scientist
# 787417   662412         318           Data Analyst
# 787434  1115667       69662      Software Engineer
# 787469   215762          66           Data Analyst
# 787512  1002637        1600    Senior Data Analyst
#
#                                           job_title       job_location  \
# 21                 Data Engineer, Product Analytics     Burlingame, CA
# 54                                    Data Engineer        Ashland, KY
# 97             DATA SCIENTIST / DATABASE PROGRAMMER         Denver, CO
# ...

# %%
# job_us = job_us.groupby('job_title_short')['salary_year_avg'].agg(['min', 'median', 'max'])
job_us = job_us.groupby('job_title_short')['salary_year_avg'].agg(['median'])
job_us
# Out:
#                              median
# job_title_short
# Business Analyst            90000.0
# Cloud Engineer             116100.0
# Data Analyst                90000.0
# Data Engineer              125000.0
# Data Scientist             130000.0
# Machine Learning Engineer  150000.0
# Senior Data Analyst        110137.5
# Senior Data Engineer       150000.0
# Senior Data Scientist      155000.0
# Software Engineer          125000.0

# %%
job_us.plot(kind='bar')
plt.ylabel('Average Salary Per Year')
plt.xlabel('Job Title')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
job_cnd = job_cnd.groupby('job_title_short')['salary_year_avg'].agg(['min', 'median', 'max'])#.sort_values(by='min', ascending=False)
job_cnd
# Out:
#                                 min    median       max
# job_title_short
# Business Analyst            64600.0   69050.0   73500.0
# Data Analyst                49566.5  100500.0  111175.0
# Data Engineer               79200.0  147500.0  188000.0
# Data Scientist              80811.0  132500.0  224000.0
# Machine Learning Engineer   99150.0  166000.0  190000.0
# Senior Data Analyst        111175.0  111175.0  120000.0
# Senior Data Engineer        64800.0  113350.0  147500.0
# Senior Data Scientist       54907.0  163750.0  231000.0
# Software Engineer           99150.0  156500.0  165000.0

# %%
plt.plot(job_cnd)
# plt.lengend()
plt.title('Jobs Data From Canada')
plt.ylabel('Average Salary Per Year')
plt.xlabel('Job Title')
plt.xticks(rotation=45, ha='right')
plt.show()
